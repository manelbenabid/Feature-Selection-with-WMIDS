# %% [markdown]
# <a href="https://colab.research.google.com/github/manelbenabid/Feature-Selection-with-WMIDS/blob/main/Lymphoma_feature_selection_and_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/manelbenabid/Feature-Selection-with-WMIDS/main/datasets/Lymphoma.csv')

# %%
df.head()
# Out:
#   GENE1835X GENE1836X GENE1865X GENE1380X GENE1933X GENE1932X GENE1931X  \
# 0      0.46      0.70      0.67     -0.23      0.00      0.09     -0.02
# 1      0.02      0.59      0.45      0.55     -0.08     -0.15     -0.05
# 2     -0.32     -0.63     -0.46     -0.28     -0.96     -1.17     -1.13
# 3     -0.51     -0.45     -0.16     -0.51     -0.58     -0.71     -0.65
# 4      0.20      0.13      0.20      0.09     -0.56      0.00      0.06
#
#    GENE1930X  GENE3129X GENE3126X  ... GENE3931X GENE2588X GENE3120X GENE6X  \
# 0      -0.57      -0.17     -0.25  ...      0.40      0.02      0.79   0.64
# 1      -0.38      -0.55      0.35  ...      0.57      0.52     -0.23   0.30
# 2      -0.89      -0.49     -0.23  ...      1.62     -0.01         ?   0.29
# 3      -0.82      -0.30     -0.22  ...      0.34      0.02      0.08   0.49
# 4      -0.15      -0.61     -0.65  ...      0.16      0.66      1.11   0.28
#
#   GENE5X  GENE3X GENE2X GENE48X GENE47X  class
# ...

# %%
df['class'].unique()
# Out:
# array(['DLBCL', 'FL', 'CLL'], dtype=object)
